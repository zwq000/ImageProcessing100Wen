# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 准备空白页面

# %%
img = np.zeros((200, 300), dtype=np.uint8)

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# # 用OpenCV画矩形

# %%
x1 = 40
y1 = 60
x2 = 100
y2 = 150
img2 = cv2.rectangle(img.copy(), (x1, y1), (x2, y2), (255), -1)
plt.imshow(img2)
plt.show()

# %% [markdown]
# # 用matplotlib画矩形并添加文字

# %%
fig, ax = plt.subplots()
ax.imshow(img)

x = 100
y = 40
w = 50
h = 60

ax.add_patch( plt.Rectangle((x, y), w, y, fill=False, edgecolor='red', linewidth=3.5) )
ax.text(x, y - 5, 'AAAAA', bbox=dict(alpha=0), fontsize=14, color='white')

plt.show()

# %% [markdown]
# # 用matplotlib画多边形

# %%
fig, ax = plt.subplots()

ax.imshow(img)

ax.add_patch(plt.Polygon([[50, 40], [150, 40], [160, 100], [40, 110], [70, 70]], fill=False, color="y"))

plt.show()

# %% [markdown]
# # 用matplotlib显示多个图像（方法一）

# %%
tate = 1
yoko = 2
plt.subplot(tate, yoko, 1)
plt.imshow(img)
plt.subplot(tate, yoko, 2)
plt.imshow(img2)
plt.subplots_adjust(left=0.075, bottom=0.05, right=0.95, top=0.95, wspace=0.15, hspace=0.15)
plt.show()

# %% [markdown]
# # 用matplotlib显示多个图像（方法二）

# %%
tate = 1
yoko = 2
fig, axs = plt.subplots(tate, yoko)
axs[0].imshow(img)
axs[1].imshow(img2)
plt.show()
